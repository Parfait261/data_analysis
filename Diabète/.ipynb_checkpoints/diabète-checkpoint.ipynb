# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('6 Data.csv')

# %% [markdown]
# # NETTOYAGE

# %%
# Changement du nom de chaque colonne 
df = df.rename(columns={'V1': 'age', 'V2': 'sex', 'V3': 'cp', 'V4': 'tresbps', 'V5': 'chol',
                       'V6': 'fbs', 'V7': 'restecg', 'V8':'thalac', 'V9': 'exang', 'V10': 'oldpeak',
                       'V11':'slope', 'V12':'ca', 'V13':'thal', 'V14':'target'})

# %%
df
# Out:
#      age  sex  cp  tresbps  chol  fbs  restecg  thalac  exang  oldpeak  slope  \
# 0     63    1   1      145   233    1        2     150      0      2.3      3
# 1     67    1   4      160   286    0        2     108      1      1.5      2
# 2     67    1   4      120   229    0        2     129      1      2.6      2
# 3     37    1   3      130   250    0        0     187      0      3.5      3
# 4     41    0   2      130   204    0        2     172      0      1.4      1
# ..   ...  ...  ..      ...   ...  ...      ...     ...    ...      ...    ...
# 298   45    1   1      110   264    0        0     132      0      1.2      2
# 299   68    1   4      144   193    1        0     141      0      3.4      2
# 300   57    1   4      130   131    0        0     115      1      1.2      2
# 301   57    0   2      130   236    0        2     174      0      0.0      2
# 302   38    1   3      138   175    0        0     173      0      0.0      1
#
#       ca thal  target
# ...

# %%
df.dtypes
# Out:
# age          int64
# sex          int64
# cp           int64
# tresbps      int64
# chol         int64
# fbs          int64
# restecg      int64
# thalac       int64
# exang        int64
# oldpeak    float64
# slope        int64
# ca          object
# thal        object
# target       int64
# dtype: object

# %%
# Modifications du types de variables
df['cp']= df['cp'].astype(object)
df['fbs']= df['fbs'].astype(object)
df['restecg']= df['restecg'].astype(object)
df['exang']= df['exang'].astype(object)
df['slope']= df['slope'].astype(object)
df['ca']= df['ca'].astype(object)
df['target']= df['target'].astype(object)

# %%
# Suppression des valeurs égale à '?'
df.replace('?', np.nan, inplace=True)

# %%
# Suppression des valeurs manquante
df.dropna(inplace = True)

# %%
# Modification des valeurs pour la variable sex 
df['sex'].replace(0, "femme", inplace=True)
df['sex'].replace(1, "homme", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2701626570.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sex'].replace(0, "femme", inplace=True)

# %%
# Modification des valeurs pour la variable cp
df['cp'].replace(1, "stable", inplace=True)
df['cp'].replace(2, "instable", inplace=True)
df['cp'].replace(3, "non ingenieuse", inplace=True)
df['cp'].replace(4, "asymptomatique", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\4188931430.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cp'].replace(1, "stable", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\4188931430.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
#Modification des valeurs du fbs
df['fbs'].replace(1, "supérieur", inplace=True)
df['fbs'].replace(0, "autres", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\1735966477.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fbs'].replace(1, "supérieur", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\1735966477.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Modifications des valurs du restecg
df['restecg'].replace(0, "normal", inplace=True)
df['restecg'].replace(1, "anomalie", inplace=True)
df['restecg'].replace(2, "hypertrophie", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2378165732.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['restecg'].replace(0, "normal", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2378165732.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Modification des valeurs du exang
df['exang'].replace(0, "non", inplace=True)
df['exang'].replace(1, "oui", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\3298518956.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['exang'].replace(0, "non", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\3298518956.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
# Modifications des valeurs de slope
df['slope'].replace(1, "en hausse", inplace=True)
df['slope'].replace(2, "stable", inplace=True)
df['slope'].replace(3, "en baisse", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2146890505.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['slope'].replace(1, "en hausse", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2146890505.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Modifications des valeurs de ca
df['ca'].replace("0.0", "absence d'anomalie", inplace=True)
df['ca'].replace("1.0", "faible", inplace=True)
df['ca'].replace("2.0", "moyen", inplace=True)
df['ca'].replace("3.0", "élevé", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\4144895790.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ca'].replace("0.0", "absence d'anomalie", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\4144895790.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Modifcation des valeurs du variables thal
df['thal'].replace("3.0", "pas d'anomalie", inplace=True)
df['thal'].replace("6.0", "sous contrôle", inplace=True)
df['thal'].replace("7.0", "instable", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2422854493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['thal'].replace("3.0", "pas d'anomalie", inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9592\2422854493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['target'].replace(2, 1, inplace=True)
df['target'].replace(3, 1, inplace=True)
df['target'].replace(4, 1, inplace=True)

# %%
df
# Out:
#      age    sex              cp  tresbps  chol        fbs       restecg  \
# 0     63  homme          stable      145   233  supérieur  hypertrophie
# 1     67  homme  asymptomatique      160   286     autres  hypertrophie
# 2     67  homme  asymptomatique      120   229     autres  hypertrophie
# 3     37  homme  non ingenieuse      130   250     autres        normal
# 4     41  femme        instable      130   204     autres  hypertrophie
# ..   ...    ...             ...      ...   ...        ...           ...
# 297   57  femme  asymptomatique      140   241     autres        normal
# 298   45  homme          stable      110   264     autres        normal
# 299   68  homme  asymptomatique      144   193  supérieur        normal
# 300   57  homme  asymptomatique      130   131     autres        normal
# 301   57  femme        instable      130   236     autres  hypertrophie
#
#      thalac exang  oldpeak      slope                  ca            thal  \
# ...

# %% [markdown]
# # Creation du modèle de regression logistique

# %%
# Importation des packages avant la création du modèle
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
# Separation des features et la variable cible 
#X = df.drop(df['target'], inplace = True)
X = df.iloc[:,:-1]
y = df.iloc[:, -1]

# %%
print(X)
print(X.shape)
# Out:
#      age    sex              cp  tresbps  chol        fbs       restecg  \
# 2     67  homme  asymptomatique      120   229     autres  hypertrophie
# 3     37  homme  non ingenieuse      130   250     autres        normal
# 4     41  femme        instable      130   204     autres  hypertrophie
# 5     56  homme        instable      120   236     autres        normal
# 6     62  femme  asymptomatique      140   268     autres  hypertrophie
# ..   ...    ...             ...      ...   ...        ...           ...
# 297   57  femme  asymptomatique      140   241     autres        normal
# 298   45  homme          stable      110   264     autres        normal
# 299   68  homme  asymptomatique      144   193  supérieur        normal
# 300   57  homme  asymptomatique      130   131     autres        normal
# 301   57  femme        instable      130   236     autres  hypertrophie
#
#      thalac exang  oldpeak      slope                  ca            thal
# ...

# %%
# Precisions des variables numériques et catégoriels de X
cat_cols = X.select_dtypes(include=['object', 'category']).columns.tolist()
num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
# Transformations des colonnes
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

# %%
# Création des jeu de données train et test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 0)

# %%
# Application de la trasformations sur train 
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.fit_transform(X_test)

print(X_train_processed.shape)
print(X_test_processed.shape)
# Out:
# (236, 28)
# (59, 28)

# %%
# Entrainement du modèle 
from sklearn.linear_model import LogisticRegression

regressor = LogisticRegression()
regressor.fit(X_train_processed, y_train)
# Out:
# LogisticRegression()

# %%
# Prediction 
y_pred = regressor.predict(X_test_processed)

# %%
# Matrice de confusion 
matrix = confusion_matrix(y_pred, y_test)
print(matrix)
sns.heatmap(matrix)
# Out:
# [[24  6]
#  [ 3 26]]
# <Axes: >
