# %%
#Import packages

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn.decomposition as PCA
import sklearn.preprocessing as StandardScaler
import scipy.stats as stats

# %%
# Import datasets

red_wine = pd.read_csv("winequality-red.csv", sep = ';')
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Import datasets

white_wine = pd.read_csv("winequality-white.csv", sep = ';')
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Checking missing values for red wine
red_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Checking missing values for white wine
white_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Checking the types of objects for red_wine
red_wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Checking the types of objects for white_wine
white_wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Adding colomn 'type'
red_wine['type'] = 'red'
white_wine['type'] = 'white'

# %%
# Creating the the principle dataset wine
wine = pd.concat([red_wine, white_wine], axis=0, ignore_index=True)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Dataset dimension
wine.shape
# Out:
# (6497, 13)

# %% [markdown]
# # Analyse univariée

# %%
# Describing numeric variable
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Describing object variable
wine.describe(include = 'object')
# Out:
#          type
# count    6497
# unique      2
# top     white
# freq     4898

# %%
sns.boxplot(data = wine)
plt.figure(figsize =(15,12))

# %%
# Visualisation for each variable 
for column in wine.columns[:-1]:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=wine, x=column, kde=True)
    plt.title(f"Histogramme de la variable {column}")
    plt.show()

    statistic, p_value = stats.normaltest(wine[column])
    if p_value < 0.05:
        print(f"La variable {column} ne suit pas une loi normale (p-value={p_value})")
    else:
        print(f"La variable {column} suit une loi normale (p-value={p_value})")
# Out:
# La variable fixed acidity ne suit pas une loi normale (p-value=0.0)
# La variable volatile acidity ne suit pas une loi normale (p-value=0.0)
# La variable citric acid ne suit pas une loi normale (p-value=2.6841653491248886e-128)
# La variable residual sugar ne suit pas une loi normale (p-value=0.0)
# La variable chlorides ne suit pas une loi normale (p-value=0.0)
# La variable free sulfur dioxide ne suit pas une loi normale (p-value=0.0)
# La variable total sulfur dioxide ne suit pas une loi normale (p-value=4.211103135341336e-13)
# La variable density ne suit pas une loi normale (p-value=3.3988166443860096e-245)
# La variable pH ne suit pas une loi normale (p-value=1.947508707989605e-39)
# La variable sulphates ne suit pas une loi normale (p-value=0.0)
# La variable alcohol ne suit pas une loi normale (p-value=1.959960392902665e-98)
# La variable quality ne suit pas une loi normale (p-value=1.1606148581928246e-11)

# %% [markdown]
# # Analyse bivarié

# %%
# Pairplot 
sns.pairplot(wine)

# %%
# Correlation table 
corr_matrix = wine.corr
corr_matrix

# Heatmap 
sns.heatmap(corr_matrix, annot= True, cmap="YlGnBu")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 6
#       3 corr_matrix
#       5 # Heatmap
# ----> 6 sns.heatmap(corr_matrix, annot= True, cmap="YlGnBu")
#       7 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %% [markdown]
# # PCA

# %%
# Importation des packages
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Séparation des données en variables explicatives (X) et variable qualitative (Y)
X = wine.iloc[:, :-1].values
y = wine.iloc[:, -1].values

# %%
# Standardisation des données
# Normaliser les données
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Réduction de dimension
pca = PCA()
X_pca=pca.fit_transform(X)

# %%
# Analyse des valeurs propres
n_components = len(pca.explained_variance_)
comp = pd.DataFrame(
    {
        "Dimension" : ["Dim" + str(x + 1) for x in range(n_components)], 
        "Valeur propre" : pca.explained_variance_ ,
        "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
        "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
    },
    columns = ["Dimension", "Valeur propre", "% variance expliquée", "% cum. var. expliquée"]
)
comp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 # Analyse des valeurs propres
# ----> 2 n_components = len(pca.explained_variance_)
#       3 comp = pd.DataFrame(
#       4     {
#       5         "Dimension" : ["Dim" + str(x + 1) for x in range(n_components)],
#    (...)     10     columns = ["Dimension", "Valeur propre", "% variance expliquée", "% cum. var. expliquée"]
#      11 )
#      12 comp
#
# NameError: name 'pca' is not defined

# %%
# Scree plot pour choisir le nombre de composantes principales
g_comp = sns.barplot(x = "Dimension", 
                y = "% variance expliquée",
                palette = ["lightseagreen"],
                data = comp)
g_comp.set(ylabel = "Variance expliquée (%)")
g_comp.figure.suptitle("Variance expliquée par dimension")
plt.axhline(y = 25, linewidth = .5, color = "dimgray", linestyle = "--") # 25 = 100 / 4 (nb dimensions)
plt.text(3.25, 26, "25%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 5
#       1 # Scree plot pour choisir le nombre de composantes principales
#       2 g_comp = sns.barplot(x = "Dimension",
#       3                 y = "% variance expliquée",
#       4                 palette = ["lightseagreen"],
# ----> 5                 data = comp)
#       6 g_comp.set(ylabel = "Variance expliquée (%)")
#       7 g_comp.figure.suptitle("Variance expliquée par dimension")
#
# NameError: name 'comp' is not defined
